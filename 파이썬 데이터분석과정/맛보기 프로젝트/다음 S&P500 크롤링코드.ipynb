# %%
import numpy as np
import pandas as pd
import requests
import urllib
import json
import time

# %%
df = pd.DataFrame(columns =['date', 'price', 'delta','volume'])

snp_date = []
snp_price = []
snp_delta = []
snp_volume = []

for i in range(404):

    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(3) # 난수가 생성 생성된 난수에 따라서 요청하는 시간 딜레이
    time.sleep(a)

    url = f'https://finance.daum.net/api/quote/US.SP500/days?symbolCode=US.SP500&page={i+1}&perPage=10&pagination=true'

    header = {
        'referer' : 'https://finance.daum.net/global/quotes/US.SP500', 
            'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_16_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Whale/2.8.108.15 Safari/537.36'
    }

    response = requests.get(url, headers = header)

    data = json.loads(response.text)

    print(i,"번째실행중")


    
    for j in range(10):

        if data['data'][j]['change'] == 'FALL':


            data['data'][j]['changePrice'] = '-' + str(data['data'][j]['changePrice'])
            data['data'][j]['changePrice'] = float(data['data'][j]['changePrice'])


        snp_date.append(data['data'][j]['date'])
        snp_price.append(data['data'][j]['tradePrice'])
        snp_delta.append(data['data'][j]['changePrice'])
        snp_volume.append(data['data'][j]['periodTradeVolume'])


df['date'] = snp_date
df['price'] = snp_price
df['volume'] = snp_volume
df['delta'] = snp_delta

df.to_csv('snp_data.csv')

# %%
df = pd.read_csv('snp_data.csv')
df2 = pd.read_csv('kosdak_data.csv')
df3 = pd.read_csv('kospi.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-654267e6cc0a> in <module>
# ----> 1 df = pd.read_csv('snp_data.csv')
#       2 df2 = pd.read_csv('kosdak_data.csv')
#       3 df3 = pd.read_csv('kospi.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
kosdak_price = []
kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(1,3977): # 날짜 다른날은 제외
    for i in range(0,4039):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
kosdak_price = []
kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(1,1250): # 날짜 다른날은 제외
    for i in range(0,1280):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
kosdak_price = []
kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(1250,2486): # 날짜 다른날은 제외
    for i in range(1280,2537):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-041a3c1ac88c> in <module>
#      17         if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
#      18
# ---> 19             date_list.append(df2.iloc[k]['date'])
#      20
#      21             kosdak_delta.append(df2.iloc[k]['delta'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1496             self._validate_integer(key, axis)
#    1497
# -> 1498             return self.obj._ixs(key, axis=axis)
# ...

# %%
kosdak_price = []
kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(2486,3977): # 날짜 다른날은 제외
    for i in range(2537,4039):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
kosdak_price = []
kosdak_delta=[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(231, 251): # 날짜 다른날은 제외
    for i in range(0,4039):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
kosdak_price = []
kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(251, 291): # 날짜 다른날은 제외
    for i in range(0,4039):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
for i in range(100):
    kosdak_price = []

kosdak_delta =[]
kosdak_volume = []

snp_price = []
snp_delta = []
snp_delta = []

kospi_price = []
kospi_delta = []
kospi_volume = []

date_list = []

for k in range(558, 679): # 날짜 다른날은 제외
    for i in range(0,4039):
        if(df2['date'][k].split('.') == df['date'][i].split(' ')[0].split('-')):
            
            date_list.append(df2.iloc[k]['date'])
            
            kosdak_delta.append(df2.iloc[k]['delta'])
            snp_delta.append(df.iloc[i]['delta'])
            kospi_delta.append(df3.iloc[k]['delta'])
            
            kosdak_volume.append(df2.iloc[k]['volume'])
            snp_volume.append(df.iloc[i]['volume'])
            kospi_volume.append(df3.iloc[k]['volume'])
            
            kosdak_price.append(df2.iloc[k]['price'])
            snp_price.append(df.iloc[i]['price'])
            kospi_price.append(df3.iloc[k]['price'])
            
            break

# %%
kosdak_price = np.array(kosdak_price)
kosdak_delta = np.array(kosdak_delta)
kosdak_delta = kosdak_delta / kosdak_price


kospi_price = np.array(kospi_price)
kospi_delta = np.array(kospi_delta)
kospi_delta = kospi_delta / kospi_price

snp_price = np.array(snp_price)
snp_delta = np.array(snp_delta)
snp_delta = snp_delta / snp_price

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = '/Library/Fonts/Arial Unicode.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
kosdak_price
# Out:
# array([627.66, 610.73, 638.17, 654.63, 656.95, 639.29, 667.99, 681.66,
#        684.78, 682.92, 688.91, 687.61, 686.59, 682.34, 676.07, 672.63,
#        672.69, 661.32, 661.24])

# %% [markdown]
# import seaborn as sns
# plt.figure(figsize=(12, 6))
# sns.scatterplot(kosdak_delta[0:3000], kospi_delta[0:3000])
# plt.ylim(-3, 3)
# plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.scatter(kosdak_delta, kospi_delta)
plt.show()

# %%
from scipy import stats

stats.pearsonr(kosdak_delta, kospi_delta)
# Out:
# (0.9098593909932742, 6.63821563136898e-08)
